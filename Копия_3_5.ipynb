# %% [markdown]
# <a href="https://colab.research.google.com/github/istvud5/Test/blob/Less1/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_3_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 5, 21)
y = (x - 2)**2 + 1
plt.plot(x, y)

# %%
s = np.pi/4
a11 = 1
a12 = 2
a21 = 2
a22 = 4
y1 = - x*a11/a12
x1 = - x*a21/a22
plt.ylim(-1,3)
plt.plot(x, y)
plt.plot(x, y1)
plt.plot(x, x1)

# %%
x = np.linspace(0, 15, 100)
y = 8*x
plt.polar(x, y)
